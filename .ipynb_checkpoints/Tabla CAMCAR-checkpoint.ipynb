# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker
plt.rcParams['figure.figsize'] = [20,15]
import seaborn as sns
sns.set()
sns.set_palette('bright')

# %%
df = pd.read_csv('All_CAMCAR_Latest_Cases_Deaths_Recovered_Active.csv', index_col=0)

# %%
df
# Out:
#                      Cases  Deaths  Recovered  Active
# Country/Region
# Dominican Republic    3614     189        208    3217
# Panama                3574      95         72    3407
# Cuba                   814      24        151     639
# Costa Rica             626       4         67     555
# Honduras               419      31          9     379
# Guatemala              180       5         19     156
# El Salvador            159       6         30     123
# Jamaica                125       5         21      99
# Trinidad and Tobago    114       8         19      87
# Aruba                   93       1         39      53
# French Guiana           86       0         51      35
# Barbados                73       5         15      53
# Cayman Islands          54       1          6      47
# Sint Maarten            53       9          5      39
# Bahamas                 49       8          6      35
# Haiti                   41       3          0      38
# ...

# %%
data = df.copy()

# %%
data['Mortality Rate'] = data['Deaths']/data['Cases']

# %%
data['Mortality Rate pct'] = data['Mortality Rate']*100

# %%
data
# Out:
#                      Cases  Deaths  Recovered  Active  Mortality Rate  \
# Country/Region
# Dominican Republic    3614     189        208    3217        0.052297
# Panama                3574      95         72    3407        0.026581
# Cuba                   814      24        151     639        0.029484
# Costa Rica             626       4         67     555        0.006390
# Honduras               419      31          9     379        0.073986
# Guatemala              180       5         19     156        0.027778
# El Salvador            159       6         30     123        0.037736
# Jamaica                125       5         21      99        0.040000
# Trinidad and Tobago    114       8         19      87        0.070175
# Aruba                   93       1         39      53        0.010753
# French Guiana           86       0         51      35        0.000000
# Barbados                73       5         15      53        0.068493
# ...

# %%
pops = [10847910, 4314767, 11326616, 5084700, 9872459, 17847727, 6476611, 2958565, 1398577, 106675, 297083, 287304, 65565, 42777, 392483, 11374286, 38531, 97765, 183458, 163958, 6608547]

# %%
data['Population'] = pops
data
# Out:
#                      Cases  Deaths  Recovered  Active  Mortality Rate  \
# Country/Region
# Dominican Republic    3614     189        208    3217        0.052297
# Panama                3574      95         72    3407        0.026581
# Cuba                   814      24        151     639        0.029484
# Costa Rica             626       4         67     555        0.006390
# Honduras               419      31          9     379        0.073986
# Guatemala              180       5         19     156        0.027778
# El Salvador            159       6         30     123        0.037736
# Jamaica                125       5         21      99        0.040000
# Trinidad and Tobago    114       8         19      87        0.070175
# Aruba                   93       1         39      53        0.010753
# French Guiana           86       0         51      35        0.000000
# Barbados                73       5         15      53        0.068493
# ...

# %%
data.columns.values
# Out:
# array(['Cases', 'Deaths', 'Recovered', 'Active', 'Mortality Rate',
#        'Mortality Rate pct', 'Population'], dtype=object)
