# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
plt.rcParams['figure.figsize'] = [25,20]
import seaborn as sns
sns.set(palette='bright')

# %%
cases = pd.read_csv('/home/andres/Documents/JupyterNBs/COVID_19_Data/COVID_Analysis/All_CAMCAR_Cases.csv',index_col=0)
deaths = pd.read_csv('/home/andres/Documents/JupyterNBs/COVID_19_Data/COVID_Analysis/All_CAMCAR_Deaths.csv',index_col=0)
recovered = pd.read_csv('/home/andres/Documents/JupyterNBs/COVID_19_Data/COVID_Analysis/All_CAMCAR_Recovered.csv',index_col=0)

# %%
cases
# Out:
#     Province/State       Country/Region  4/20/20  4/21/20
# 0              NaN   Dominican Republic     4964     5044
# 1              NaN               Panama     4467     4658
# 2              NaN                 Cuba     1087     1137
# 3              NaN           Costa Rica      662      669
# 4              NaN             Honduras      477      494
# 5              NaN            Guatemala      289      294
# 6              NaN          El Salvador      218      225
# 7              NaN              Jamaica      223      223
# 8              NaN  Trinidad and Tobago      114      115
# 9    French Guiana               France       97       97
# 10           Aruba          Netherlands       97       97
# 11             NaN             Barbados       75       75
# 12    Sint Maarten          Netherlands       67       67
# 13  Cayman Islands       United Kingdom       66       66
# 14             NaN              Bahamas       60       65
# 15             NaN                Haiti       57       57
# 16       St Martin               France       37       37
# 17             NaN  Antigua and Barbuda       23       23
# 18             NaN          Saint Lucia       15       15
# 19         Curacao          Netherlands       14       14
# 20             NaN            Nicaragua       10       10

# %%
deaths.head()
# Out:
#   Province/State      Country/Region  4/20/20  4/21/20
# 0            NaN  Dominican Republic      235      245
# 1            NaN              Panama      126      136
# 2            NaN            Honduras       46       46
# 3            NaN                Cuba       36       38
# 4   Sint Maarten         Netherlands       10       10

# %%
recovered.head()
# Out:
#   Province/State      Country/Region  4/20/20  4/21/20
# 0            NaN  Dominican Republic      416      463
# 1            NaN                Cuba      285      309
# 2            NaN              Panama      165      204
# 3            NaN          Costa Rica      124      150
# 4  French Guiana              France       69       76

# %%
names_cases = cases[cases['Province/State'].notna()].iloc[:,0]
indices = names_cases.index

# %%
cases.iloc[indices, 1] = names_cases

# %%
cases.drop('Province/State', axis=1, inplace=True)

# %%
cases
# Out:
#          Country/Region  4/20/20  4/21/20
# 0    Dominican Republic     4964     5044
# 1                Panama     4467     4658
# 2                  Cuba     1087     1137
# 3            Costa Rica      662      669
# 4              Honduras      477      494
# 5             Guatemala      289      294
# 6           El Salvador      218      225
# 7               Jamaica      223      223
# 8   Trinidad and Tobago      114      115
# 9         French Guiana       97       97
# 10                Aruba       97       97
# 11             Barbados       75       75
# 12         Sint Maarten       67       67
# 13       Cayman Islands       66       66
# 14              Bahamas       60       65
# 15                Haiti       57       57
# 16            St Martin       37       37
# 17  Antigua and Barbuda       23       23
# 18          Saint Lucia       15       15
# 19              Curacao       14       14
# 20            Nicaragua       10       10

# %%
names_deaths = deaths[deaths['Province/State'].notna()].iloc[:,0]
indices = names_deaths.index
deaths.iloc[indices, 1] = names_deaths
deaths.drop('Province/State', axis=1, inplace=True)
deaths
# Out:
#          Country/Region  4/20/20  4/21/20
# 0    Dominican Republic      235      245
# 1                Panama      126      136
# 2              Honduras       46       46
# 3                  Cuba       36       38
# 4          Sint Maarten       10       10
# 5               Bahamas        9        9
# 6   Trinidad and Tobago        8        8
# 7           El Salvador        7        7
# 8             Guatemala        7        7
# 9            Costa Rica        6        6
# 10              Jamaica        5        6
# 11             Barbados        5        5
# 12  Antigua and Barbuda        3        3
# 13                Haiti        3        3
# 14                Aruba        2        2
# 15            Nicaragua        2        2
# 16            St Martin        2        2
# 17              Curacao        1        1
# 18        French Guiana        1        1
# 19       Cayman Islands        1        1
# 20          Saint Lucia        0        0

# %%
names_recovered = recovered[recovered['Province/State'].notna()].iloc[:,0]
indices = names_recovered.index
recovered.iloc[indices, 1] = names_recovered
recovered.drop('Province/State', axis=1, inplace=True)
recovered
# Out:
#          Country/Region  4/20/20  4/21/20
# 0    Dominican Republic      416      463
# 1                  Cuba      285      309
# 2                Panama      165      204
# 3            Costa Rica      124      150
# 4         French Guiana       69       76
# 5                 Aruba       49       51
# 6           El Salvador       46       48
# 7              Honduras       25       29
# 8   Trinidad and Tobago       22       28
# 9               Jamaica       27       27
# 10             Barbados       19       25
# 11            Guatemala       21       24
# 12            St Martin       19       19
# 13          Saint Lucia       13       13
# 14              Bahamas       11       12
# 15         Sint Maarten       12       12
# 16              Curacao       11       11
# 17  Antigua and Barbuda        3        7
# 18       Cayman Islands        7        7
# 19            Nicaragua        6        7
# 20                Haiti        0        0

# %%
cases.set_index('Country/Region', inplace=True)
deaths.set_index('Country/Region', inplace=True)
recovered.set_index('Country/Region', inplace=True)

# %%
cases
# Out:
#                      4/20/20  4/21/20
# Country/Region
# Dominican Republic      4964     5044
# Panama                  4467     4658
# Cuba                    1087     1137
# Costa Rica               662      669
# Honduras                 477      494
# Guatemala                289      294
# El Salvador              218      225
# Jamaica                  223      223
# Trinidad and Tobago      114      115
# French Guiana             97       97
# Aruba                     97       97
# Barbados                  75       75
# Sint Maarten              67       67
# Cayman Islands            66       66
# Bahamas                   60       65
# Haiti                     57       57
# St Martin                 37       37
# Antigua and Barbuda       23       23
# Saint Lucia               15       15
# Curacao                   14       14
# Nicaragua                 10       10

# %%
deaths
# Out:
#                      4/20/20  4/21/20
# Country/Region
# Dominican Republic       235      245
# Panama                   126      136
# Honduras                  46       46
# Cuba                      36       38
# Sint Maarten              10       10
# Bahamas                    9        9
# Trinidad and Tobago        8        8
# El Salvador                7        7
# Guatemala                  7        7
# Costa Rica                 6        6
# Jamaica                    5        6
# Barbados                   5        5
# Antigua and Barbuda        3        3
# Haiti                      3        3
# Aruba                      2        2
# Nicaragua                  2        2
# St Martin                  2        2
# Curacao                    1        1
# French Guiana              1        1
# Cayman Islands             1        1
# Saint Lucia                0        0

# %%
indices = cases.index
indices
# Out:
# Index(['Dominican Republic', 'Panama', 'Cuba', 'Costa Rica', 'Honduras',
#        'Guatemala', 'El Salvador', 'Jamaica', 'Trinidad and Tobago',
#        'French Guiana', 'Aruba', 'Barbados', 'Sint Maarten', 'Cayman Islands',
#        'Bahamas', 'Haiti', 'St Martin', 'Antigua and Barbuda', 'Saint Lucia',
#        'Curacao', 'Nicaragua'],
#       dtype='object', name='Country/Region')

# %%
deaths = deaths.reindex(indices)
deaths
# Out:
#                      4/20/20  4/21/20
# Country/Region
# Dominican Republic       235      245
# Panama                   126      136
# Cuba                      36       38
# Costa Rica                 6        6
# Honduras                  46       46
# Guatemala                  7        7
# El Salvador                7        7
# Jamaica                    5        6
# Trinidad and Tobago        8        8
# French Guiana              1        1
# Aruba                      2        2
# Barbados                   5        5
# Sint Maarten              10       10
# Cayman Islands             1        1
# Bahamas                    9        9
# Haiti                      3        3
# St Martin                  2        2
# Antigua and Barbuda        3        3
# Saint Lucia                0        0
# Curacao                    1        1
# Nicaragua                  2        2

# %%
recovered = recovered.reindex(indices)
recovered
# Out:
#                      4/20/20  4/21/20
# Country/Region
# Dominican Republic       416      463
# Panama                   165      204
# Cuba                     285      309
# Costa Rica               124      150
# Honduras                  25       29
# Guatemala                 21       24
# El Salvador               46       48
# Jamaica                   27       27
# Trinidad and Tobago       22       28
# French Guiana             69       76
# Aruba                     49       51
# Barbados                  19       25
# Sint Maarten              12       12
# Cayman Islands             7        7
# Bahamas                   11       12
# Haiti                      0        0
# St Martin                 19       19
# Antigua and Barbuda        3        7
# Saint Lucia               13       13
# Curacao                   11       11
# Nicaragua                  6        7

# %%
day = cases.columns.values[-1]
day
# Out:
# '4/21/20'

# %%
active = pd.DataFrame(cases - deaths - recovered)

# %%
active
# Out:
#                      4/20/20  4/21/20
# Country/Region
# Dominican Republic      4313     4336
# Panama                  4176     4318
# Cuba                     766      790
# Costa Rica               532      513
# Honduras                 406      419
# Guatemala                261      263
# El Salvador              165      170
# Jamaica                  191      190
# Trinidad and Tobago       84       79
# French Guiana             27       20
# Aruba                     46       44
# Barbados                  51       45
# Sint Maarten              45       45
# Cayman Islands            58       58
# Bahamas                   40       44
# Haiti                     54       54
# St Martin                 16       16
# Antigua and Barbuda       17       13
# Saint Lucia                2        2
# Curacao                    2        2
# Nicaragua                  2        1

# %%
ax = cases[day].plot.barh(color=[1,0,0,1], x='Country/Region', y=day, label='Total Confirmed Cases')
active[day].plot.barh(ax=ax, color=[1,0.9,0,1], label='Active Cases')
deaths[day].plot.barh(ax=ax, color=[0,0,0,1], label='Deaths')
recovered[day].plot.barh(ax=ax, color=[0,1,0,0.5], label='Recovered')
plt.yticks(fontsize=20, rotation=0)
plt.ylabel(day, fontsize=30)
plt.xticks(np.arange(0, cases.iloc[cases[day].argmax(), 1], 25),fontsize=15, rotation=45)
plt.title('COVID-19 CAMCAR', fontsize=25)
plt.legend(loc='best', fontsize=25)
plt.show()

# %%
joined_data = pd.DataFrame(cases[day])
joined_data
# Out:
#                      4/21/20
# Country/Region
# Dominican Republic      5044
# Panama                  4658
# Cuba                    1137
# Costa Rica               669
# Honduras                 494
# Guatemala                294
# El Salvador              225
# Jamaica                  223
# Trinidad and Tobago      115
# French Guiana             97
# Aruba                     97
# Barbados                  75
# Sint Maarten              67
# Cayman Islands            66
# Bahamas                   65
# Haiti                     57
# St Martin                 37
# Antigua and Barbuda       23
# Saint Lucia               15
# Curacao                   14
# Nicaragua                 10

# %%
joined_data.rename(columns={day: 'Cases'}, inplace=True)

# %%
joined_data['Deaths'] = deaths[day]

# %%
joined_data['Recovered'] = recovered[day]

# %%
joined_data['Active'] = active[day]

# %%
joined_data['New Cases'] = cases.iloc[:,-1] - cases.iloc[:,-2]

# %%
joined_data
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases
# Country/Region
# Dominican Republic    5044     245        463    4336         80
# Panama                4658     136        204    4318        191
# Cuba                  1137      38        309     790         50
# Costa Rica             669       6        150     513          7
# Honduras               494      46         29     419         17
# Guatemala              294       7         24     263          5
# El Salvador            225       7         48     170          7
# Jamaica                223       6         27     190          0
# Trinidad and Tobago    115       8         28      79          1
# French Guiana           97       1         76      20          0
# Aruba                   97       2         51      44          0
# Barbados                75       5         25      45          0
# Sint Maarten            67      10         12      45          0
# Cayman Islands          66       1          7      58          0
# Bahamas                 65       9         12      44          5
# Haiti                   57       3          0      54          0
# St Martin               37       2         19      16          0
# Antigua and Barbuda     23       3          7      13          0
# Saint Lucia             15       0         13       2          0
# Curacao                 14       1         11       2          0
# Nicaragua               10       2          7       1          0

# %%
joined_data.to_csv('All_CAMCAR_Latest_Cases_Deaths_Recovered_Active.csv', index=True)

# %%
joined_data.plot(kind='barh', cmap=plt.get_cmap('jet'))
plt.yticks(fontsize=20, rotation=0)
plt.ylabel(day, fontsize=30)
plt.xticks(np.arange(0, cases.iloc[cases[day].argmax(), 1], 50),fontsize=15, rotation=45)
plt.title('COVID-19 CAMCAR Data', fontsize=25)
plt.legend(loc='best', fontsize=25)
plt.show()

# %%
joined_data.describe()
# Out:
#              Cases      Deaths   Recovered       Active   New Cases
# count    21.000000   21.000000   21.000000    21.000000   21.000000
# mean    642.000000   25.619048   72.476190   543.904762   17.285714
# std    1426.727339   58.639130  118.105723  1273.809558   44.465878
# min      10.000000    0.000000    0.000000     1.000000    0.000000
# 25%      57.000000    2.000000   12.000000    20.000000    0.000000
# 50%      97.000000    6.000000   25.000000    54.000000    0.000000
# 75%     294.000000    9.000000   51.000000   263.000000    7.000000
# max    5044.000000  245.000000  463.000000  4336.000000  191.000000

# %%
# cols =joined_data.columns.values
# cols[0], cols[1], cols[2], cols[3] = cols[1], cols[2], cols[3], cols[0]
# cols

# %%
data_bar = joined_data.sort_values(by=['Cases'])
#data_bar = data_bar[cols]
data_bar
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases
# Country/Region
# Nicaragua               10       2          7       1          0
# Curacao                 14       1         11       2          0
# Saint Lucia             15       0         13       2          0
# Antigua and Barbuda     23       3          7      13          0
# St Martin               37       2         19      16          0
# Haiti                   57       3          0      54          0
# Bahamas                 65       9         12      44          5
# Cayman Islands          66       1          7      58          0
# Sint Maarten            67      10         12      45          0
# Barbados                75       5         25      45          0
# Aruba                   97       2         51      44          0
# French Guiana           97       1         76      20          0
# Trinidad and Tobago    115       8         28      79          1
# Jamaica                223       6         27     190          0
# El Salvador            225       7         48     170          7
# Guatemala              294       7         24     263          5
# Honduras               494      46         29     419         17
# Costa Rica             669       6        150     513          7
# Cuba                  1137      38        309     790         50
# Panama                4658     136        204    4318        191
# Dominican Republic    5044     245        463    4336         80

# %%
data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].plot(kind='barh', cmap=plt.get_cmap('seismic'))
plt.yticks(fontsize=20, rotation=0)
plt.ylabel('', fontsize=30)
plt.xticks(np.arange(0, cases.iloc[cases[day].argmax(), 1], 100),fontsize=15, rotation=45)
plt.title('COVID-19 CAMCAR Data   ' + day, fontsize=25)
plt.legend(loc=4, fontsize=25)
columns = data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].shape[1]
rows = data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].shape[0]
ys = np.array(range(rows))
for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,0] + 5, 
        y=ys[i] - 0.25, 
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,0], 
        size=20
    )


for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,1] + 5, 
        y=ys[i] -0.1 if data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,2] != 0 else 0.1, 
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,1], 
        size=18
    )


for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,2] + 10, 
        y=ys[i] , 
        s= data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,2], 
        size=18
    )

for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,3] + 5, 
        y=ys[i] + 0.15, 
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,3], 
        size=20
    )
plt.savefig('/home/andres/Documents/JupyterNBs/COVID_19_Data/Figures/CAMCAR_Largest.png')
plt.show()

# %%
data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[1,0]
# Out:
# 223

# %%
data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].columns.values[0]
# Out:
# 'Cases'

# %%
data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)]
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases
# Country/Region
# Trinidad and Tobago    115       8         28      79          1
# Jamaica                223       6         27     190          0
# El Salvador            225       7         48     170          7
# Guatemala              294       7         24     263          5
# Honduras               494      46         29     419         17
# Costa Rica             669       6        150     513          7
# Cuba                  1137      38        309     790         50
# Panama                4658     136        204    4318        191
# Dominican Republic    5044     245        463    4336         80

# %%
data_bar.plot(kind='barh', cmap=plt.get_cmap('seismic'))
plt.yticks(fontsize=20, rotation=0)
plt.ylabel(day, fontsize=30)
plt.xticks(np.arange(0, cases.iloc[cases[day].argmax(), 1], 100),fontsize=15, rotation=45)
plt.title('COVID-19 CAMCAR Data', fontsize=25)
plt.legend(loc=4, fontsize=25)
plt.savefig('/home/andres/Documents/JupyterNBs/COVID_19_Data/Figures/CAMCAR_All.png')
plt.show()

# %%
data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].plot(
    kind='barh', cmap=plt.get_cmap('seismic')
)
plt.yticks(fontsize=20, rotation=0)
plt.ylabel('', fontsize=30)
plt.xticks(np.arange(0, cases.iloc[cases[day].argmax(), 1].round(-1), 100),fontsize=15, rotation=45)
plt.xscale('log')
#plt.ticklabel_format(style='plain', axis='y')
plt.title('COVID-19 CAMCAR Data   ' + day, fontsize=25)
plt.legend(loc=4, fontsize=25)
columns = data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].shape[1]
rows = data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].shape[0]
ys = np.array(range(rows))
for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,0] + 5, 
        y=ys[i] - 0.25, 
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,0], 
        size=20
    )


for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,1] + 0.1  if data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,1] != 0 else 0.9, 
        y=ys[i] -0.125, 
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,1], 
        size=18
    )


for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,2] + 0.1, 
        y=ys[i] , 
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,2], 
        size=18
    )

for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,3] + 5, 
        y=ys[i] + 0.15, 
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,3], 
        size=20
    )
plt.savefig('/home/andres/Documents/JupyterNBs/COVID_19_Data/Figures/CAMCAR_Largest_log.png')
plt.show()
