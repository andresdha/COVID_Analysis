# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker
plt.rcParams['figure.figsize'] = [20,15]
import seaborn as sns
sns.set()
sns.set_palette('bright')

# %%
df = pd.read_csv('All_CAMCAR_Latest_Cases_Deaths_Recovered_Active.csv', index_col=0)

# %%
df
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases
# Country/Region
# Dominican Republic   88127    1501      56760   29866       1004
# Panama               83754    1827      58274   23653        964
# Guatemala            64881    2467      53362    9052       1034
# Honduras             52298    1608       7867   42823        628
# Costa Rica           30409     321       9660   20428        766
# El Salvador          23717     633      11388   11696        255
# French Guiana         8711      54       8112     545         54
# Haiti                 7949     196       5337    2416         28
# Nicaragua             4311     133       2913    1265          0
# Cuba                  3482      88       2863     531         74
# Bahamas               1531      22        209    1300        107
# Aruba                 1296       5        277    1014         91
# Jamaica               1192      14        772     406         46
# ...

# %%
data = df.copy()

# %%
data['Mortality Ratio'] = data['Deaths']/data['Cases']

# %%
data['Mortality pct'] = data['Mortality Ratio']*100

# %%
data
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases  \
# Country/Region
# Dominican Republic   88127    1501      56760   29866       1004
# Panama               83754    1827      58274   23653        964
# Guatemala            64881    2467      53362    9052       1034
# Honduras             52298    1608       7867   42823        628
# Costa Rica           30409     321       9660   20428        766
# El Salvador          23717     633      11388   11696        255
# French Guiana         8711      54       8112     545         54
# Haiti                 7949     196       5337    2416         28
# Nicaragua             4311     133       2913    1265          0
# Cuba                  3482      88       2863     531         74
# Bahamas               1531      22        209    1300        107
# Aruba                 1296       5        277    1014         91
# Jamaica               1192      14        772     406         46
# ...

# %%
data
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases  \
# Country/Region
# Dominican Republic   88127    1501      56760   29866       1004
# Panama               83754    1827      58274   23653        964
# Guatemala            64881    2467      53362    9052       1034
# Honduras             52298    1608       7867   42823        628
# Costa Rica           30409     321       9660   20428        766
# El Salvador          23717     633      11388   11696        255
# French Guiana         8711      54       8112     545         54
# Haiti                 7949     196       5337    2416         28
# Nicaragua             4311     133       2913    1265          0
# Cuba                  3482      88       2863     531         74
# Bahamas               1531      22        209    1300        107
# Aruba                 1296       5        277    1014         91
# Jamaica               1192      14        772     406         46
# ...

# %%
data.loc['Dominican Republic', 'Population'] = 10847910
data.loc['Panama', 'Population'] = 4314767
data.loc['Honduras', 'Population'] = 9904607
data.loc['Cuba', 'Population'] = 11326616
data.loc['Guatemala', 'Population'] = 17915568
data.loc['El Salvador', 'Population'] = 6486205
data.loc['Costa Rica', 'Population'] = 5094118
data.loc['Jamaica', 'Population'] = 2961167
data.loc['Trinidad and Tobago', 'Population'] = 1399488
data.loc['Aruba', 'Population'] = 106766
data.loc['Bahamas', 'Population'] = 393244
data.loc['Barbados', 'Population'] = 287375
data.loc['Nicaragua', 'Population'] = 6624554
data.loc['Saint Lucia', 'Population'] = 183627
data.loc['Curacao', 'Population'] = 164093
data.loc['Guyana', 'Population'] = 786552
data.loc['Antigua and Barbuda', 'Population'] = 97929
data.loc['Haiti', 'Population'] = 11402528
data.loc['Cayman Islands', 'Population'] = 65757
data.loc['St Martin', 'Population'] = 38666

# %%
data.columns.values
# Out:
# array(['Cases', 'Deaths', 'Recovered', 'Active', 'New Cases',
#        'Mortality Ratio', 'Mortality pct', 'Population'], dtype=object)

# %% [markdown]
# ##### Rate of infection
#
# Defined as: $$\frac{Confirmed}{Population/100000}$$

# %%
data['Rate of Infection'] = data['Cases']/(data['Population']/100000)

# %%
data
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases  \
# Country/Region
# Dominican Republic   88127    1501      56760   29866       1004
# Panama               83754    1827      58274   23653        964
# Guatemala            64881    2467      53362    9052       1034
# Honduras             52298    1608       7867   42823        628
# Costa Rica           30409     321       9660   20428        766
# El Salvador          23717     633      11388   11696        255
# French Guiana         8711      54       8112     545         54
# Haiti                 7949     196       5337    2416         28
# Nicaragua             4311     133       2913    1265          0
# Cuba                  3482      88       2863     531         74
# Bahamas               1531      22        209    1300        107
# Aruba                 1296       5        277    1014         91
# Jamaica               1192      14        772     406         46
# ...

# %% [markdown]
# #### Daily Incidence pct
#
# $$\frac{New Cases}{Active}*100$$

# %%
data['Daily Incidence pct'] = data['New Cases']/data['Active']*100
data
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases  \
# Country/Region
# Dominican Republic   88127    1501      56760   29866       1004
# Panama               83754    1827      58274   23653        964
# Guatemala            64881    2467      53362    9052       1034
# Honduras             52298    1608       7867   42823        628
# Costa Rica           30409     321       9660   20428        766
# El Salvador          23717     633      11388   11696        255
# French Guiana         8711      54       8112     545         54
# Haiti                 7949     196       5337    2416         28
# Nicaragua             4311     133       2913    1265          0
# Cuba                  3482      88       2863     531         74
# Bahamas               1531      22        209    1300        107
# Aruba                 1296       5        277    1014         91
# Jamaica               1192      14        772     406         46
# ...

# %%
data.columns.values
# Out:
# array(['Cases', 'Deaths', 'Recovered', 'Active', 'New Cases',
#        'Mortality Ratio', 'Mortality pct', 'Population',
#        'Rate of Infection', 'Daily Incidence pct'], dtype=object)

# %%
cols = ['Population', 'Cases', 'Deaths', 'Recovered', 'Active', 'New Cases',
       'Mortality Ratio', 'Mortality pct', 
       'Rate of Infection', 'Daily Incidence pct']

# %%
temp = data[cols]
temp
# Out:
#                      Population  Cases  Deaths  Recovered  Active  New Cases  \
# Country/Region
# Dominican Republic   10847910.0  88127    1501      56760   29866       1004
# Panama                4314767.0  83754    1827      58274   23653        964
# Guatemala            17915568.0  64881    2467      53362    9052       1034
# Honduras              9904607.0  52298    1608       7867   42823        628
# Costa Rica            5094118.0  30409     321       9660   20428        766
# El Salvador           6486205.0  23717     633      11388   11696        255
# French Guiana               NaN   8711      54       8112     545         54
# Haiti                11402528.0   7949     196       5337    2416         28
# Nicaragua             6624554.0   4311     133       2913    1265          0
# Cuba                 11326616.0   3482      88       2863     531         74
# Bahamas                393244.0   1531      22        209    1300        107
# ...

# %%
temp.drop(['French Guiana', 'Sint Maarten'], axis=0, inplace=True)
# Out:
# /home/andres/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
result = temp.copy()

# %%
result.Population = result.Population.astype(int)
result
# Out:
#                      Population  Cases  Deaths  Recovered  Active  New Cases  \
# Country/Region
# Dominican Republic     10847910  88127    1501      56760   29866       1004
# Panama                  4314767  83754    1827      58274   23653        964
# Guatemala              17915568  64881    2467      53362    9052       1034
# Honduras                9904607  52298    1608       7867   42823        628
# Costa Rica              5094118  30409     321       9660   20428        766
# El Salvador             6486205  23717     633      11388   11696        255
# Haiti                  11402528   7949     196       5337    2416         28
# Nicaragua               6624554   4311     133       2913    1265          0
# Cuba                   11326616   3482      88       2863     531         74
# Bahamas                  393244   1531      22        209    1300        107
# Aruba                    106766   1296       5        277    1014         91
# ...

# %%
result = result.round(3)
result.to_csv('CAMCAR_COVID_Cases.csv')

# %%
result
# Out:
#                      Population  Cases  Deaths  Recovered  Active  New Cases  \
# Country/Region
# Dominican Republic     10847910  88127    1501      56760   29866       1004
# Panama                  4314767  83754    1827      58274   23653        964
# Guatemala              17915568  64881    2467      53362    9052       1034
# Honduras                9904607  52298    1608       7867   42823        628
# Costa Rica              5094118  30409     321       9660   20428        766
# El Salvador             6486205  23717     633      11388   11696        255
# Haiti                  11402528   7949     196       5337    2416         28
# Nicaragua               6624554   4311     133       2913    1265          0
# Cuba                   11326616   3482      88       2863     531         74
# Bahamas                  393244   1531      22        209    1300        107
# Aruba                    106766   1296       5        277    1014         91
# ...

# %%
ax = result['Rate of Infection'].sort_values(ascending=False).plot(kind='bar')
plt.show()

# %%
result['Mortality pct'].sort_values(ascending=False).round(2)
# Out:
# Country/Region
# Barbados               4.52
# St Martin              4.13
# Guatemala              3.80
# Guyana                 3.48
# Antigua and Barbuda    3.19
# Nicaragua              3.08
# Honduras               3.08
# Curacao                2.78
# El Salvador            2.67
# Cuba                   2.53
# Haiti                  2.47
# Panama                 2.18
# Trinidad and Tobago    1.75
# Dominican Republic     1.70
# Bahamas                1.44
# Jamaica                1.17
# Costa Rica             1.06
# Cayman Islands         0.49
# Aruba                  0.39
# Saint Lucia            0.00
# Name: Mortality pct, dtype: float64

# %%
result['Mortality pct'].describe().round(2)
# Out:
# count    20.00
# mean      2.29
# std       1.27
# min       0.00
# 25%       1.37
# 50%       2.50
# 75%       3.11
# max       4.52
# Name: Mortality pct, dtype: float64

# %%
result['Mortality pct'].plot(kind='box', )
plt.show()
