# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker
plt.rcParams['figure.figsize'] = [20,15]
import seaborn as sns
sns.set()
sns.set_palette('bright')

# %%
df = pd.read_csv('All_CAMCAR_Latest_Cases_Deaths_Recovered_Active.csv', index_col=0)

# %%
df
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases
# Country/Region
# Dominican Republic   23686     615      14133    8938        415
# Panama               21962     457      13774    7731        540
# Guatemala            10706     418       2096    8192        434
# Honduras              9656     330       1075    8251        478
# Haiti                 4547      80         24    4443        106
# El Salvador           3941      76       2041    1824        115
# Cuba                  2273      84       1994     195         11
# Nicaragua             1823      64       1238     521        359
# Costa Rica            1796      12        794     990         52
# French Guiana         1421       5        619     797         95
# Jamaica                621      10        449     162          0
# Cayman Islands         193       1        123      69          6
# Trinidad and Tobago    123       8        109       6          0
# ...

# %%
data = df.copy()

# %%
data['Mortality Ratio'] = data['Deaths']/data['Cases']

# %%
data['Mortality pct'] = data['Mortality Ratio']*100

# %%
data
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases  \
# Country/Region
# Dominican Republic   23686     615      14133    8938        415
# Panama               21962     457      13774    7731        540
# Guatemala            10706     418       2096    8192        434
# Honduras              9656     330       1075    8251        478
# Haiti                 4547      80         24    4443        106
# El Salvador           3941      76       2041    1824        115
# Cuba                  2273      84       1994     195         11
# Nicaragua             1823      64       1238     521        359
# Costa Rica            1796      12        794     990         52
# French Guiana         1421       5        619     797         95
# Jamaica                621      10        449     162          0
# Cayman Islands         193       1        123      69          6
# Trinidad and Tobago    123       8        109       6          0
# ...

# %%
pops = [11108011, 4291013, 11495023, 5044015, 9721007, 17907008, 6480013, 2911015, 1376715, 106521, 297083, 287425, 65565, 42777, 405714, 11374286, 38531, 97765, 181214, 163527, 6416009]

# %%
data
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases  \
# Country/Region
# Dominican Republic   23686     615      14133    8938        415
# Panama               21962     457      13774    7731        540
# Guatemala            10706     418       2096    8192        434
# Honduras              9656     330       1075    8251        478
# Haiti                 4547      80         24    4443        106
# El Salvador           3941      76       2041    1824        115
# Cuba                  2273      84       1994     195         11
# Nicaragua             1823      64       1238     521        359
# Costa Rica            1796      12        794     990         52
# French Guiana         1421       5        619     797         95
# Jamaica                621      10        449     162          0
# Cayman Islands         193       1        123      69          6
# Trinidad and Tobago    123       8        109       6          0
# ...

# %%
data['Population'] = pops
data.loc['Dominican Republic', 'Population'] = pops[0]
data.loc['Panama', 'Population'] = pops[1]
data.loc['Honduras', 'Population'] = pops[4]
data.loc['Cuba', 'Population'] = pops[2]
data.loc['Guatemala', 'Population'] = pops[5]
data.loc['El Salvador', 'Population'] = pops[6]
data.loc['Costa Rica', 'Population'] = pops[3]
data.loc['Jamaica', 'Population'] = pops[7]
data.loc['Trinidad and Tobago', 'Population'] = pops[8]
data.loc['Aruba', 'Population'] = pops[9]
data.loc['Bahamas', 'Population'] = pops[14]
data.loc['Barbados', 'Population'] = pops[11]
data.loc['Nicaragua', 'Population'] = pops[-1]
data.loc['Saint Lucia', 'Population'] = pops[-3]
data.loc['Curacao', 'Population'] = pops[-2]

# %%
data.columns.values
# Out:
# array(['Cases', 'Deaths', 'Recovered', 'Active', 'New Cases',
#        'Mortality Ratio', 'Mortality pct', 'Population'], dtype=object)

# %% [markdown]
# ##### Rate of infection
#
# Defined as: $$\frac{Confirmed}{Population/100000}$$

# %%
data['Rate of Infection'] = data['Cases']/(data['Population']/100000)

# %%
data
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases  \
# Country/Region
# Dominican Republic   23686     615      14133    8938        415
# Panama               21962     457      13774    7731        540
# Guatemala            10706     418       2096    8192        434
# Honduras              9656     330       1075    8251        478
# Haiti                 4547      80         24    4443        106
# El Salvador           3941      76       2041    1824        115
# Cuba                  2273      84       1994     195         11
# Nicaragua             1823      64       1238     521        359
# Costa Rica            1796      12        794     990         52
# French Guiana         1421       5        619     797         95
# Jamaica                621      10        449     162          0
# Cayman Islands         193       1        123      69          6
# Trinidad and Tobago    123       8        109       6          0
# ...

# %% [markdown]
# #### Daily Incidence pct
#
# $$\frac{New Cases}{Confirmed}*100$$

# %%
data['Daily Incidence pct'] = data['New Cases']/data['Cases']*100
data
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases  \
# Country/Region
# Dominican Republic   23686     615      14133    8938        415
# Panama               21962     457      13774    7731        540
# Guatemala            10706     418       2096    8192        434
# Honduras              9656     330       1075    8251        478
# Haiti                 4547      80         24    4443        106
# El Salvador           3941      76       2041    1824        115
# Cuba                  2273      84       1994     195         11
# Nicaragua             1823      64       1238     521        359
# Costa Rica            1796      12        794     990         52
# French Guiana         1421       5        619     797         95
# Jamaica                621      10        449     162          0
# Cayman Islands         193       1        123      69          6
# Trinidad and Tobago    123       8        109       6          0
# ...

# %%
data.columns.values
# Out:
# array(['Cases', 'Deaths', 'Recovered', 'Active', 'New Cases',
#        'Mortality Ratio', 'Mortality pct', 'Population',
#        'Rate of Infection', 'Daily Incidence pct'], dtype=object)

# %%
cols = ['Population', 'Cases', 'Deaths', 'Recovered', 'Active', 'New Cases',
       'Mortality Ratio', 'Mortality pct', 
       'Rate of Infection', 'Daily Incidence pct']

# %%
temp = data[cols]
temp
# Out:
#                      Population  Cases  Deaths  Recovered  Active  New Cases  \
# Country/Region
# Dominican Republic     11108011  23686     615      14133    8938        415
# Panama                  4291013  21962     457      13774    7731        540
# Guatemala              17907008  10706     418       2096    8192        434
# Honduras                9721007   9656     330       1075    8251        478
# Haiti                   9721007   4547      80         24    4443        106
# El Salvador             6480013   3941      76       2041    1824        115
# Cuba                   11495023   2273      84       1994     195         11
# Nicaragua               6416009   1823      64       1238     521        359
# Costa Rica              5044015   1796      12        794     990         52
# French Guiana            106521   1421       5        619     797         95
# Jamaica                 2911015    621      10        449     162          0
# ...

# %%
temp.drop(['French Guiana', 'Cayman Islands', 'Sint Maarten', 'Haiti', 'St Martin', 'Antigua and Barbuda'], axis=0, inplace=True)
# Out:
# /home/andres/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
result = temp.copy()

# %%
result
# Out:
#                      Population  Cases  Deaths  Recovered  Active  New Cases  \
# Country/Region
# Dominican Republic     11108011  23686     615      14133    8938        415
# Panama                  4291013  21962     457      13774    7731        540
# Guatemala              17907008  10706     418       2096    8192        434
# Honduras                9721007   9656     330       1075    8251        478
# El Salvador             6480013   3941      76       2041    1824        115
# Cuba                   11495023   2273      84       1994     195         11
# Nicaragua               6416009   1823      64       1238     521        359
# Costa Rica              5044015   1796      12        794     990         52
# Jamaica                 2911015    621      10        449     162          0
# Trinidad and Tobago     1376715    123       8        109       6          0
# Bahamas                  405714    104      11         72      21          1
# ...

# %%
result = result.round(2)
result.to_csv('CAMCAR_COVID_Cases.csv')

# %%
result
# Out:
#                      Population  Cases  Deaths  Recovered  Active  New Cases  \
# Country/Region
# Dominican Republic     11108011  23686     615      14133    8938        415
# Panama                  4291013  21962     457      13774    7731        540
# Guatemala              17907008  10706     418       2096    8192        434
# Honduras                9721007   9656     330       1075    8251        478
# El Salvador             6480013   3941      76       2041    1824        115
# Cuba                   11495023   2273      84       1994     195         11
# Nicaragua               6416009   1823      64       1238     521        359
# Costa Rica              5044015   1796      12        794     990         52
# Jamaica                 2911015    621      10        449     162          0
# Trinidad and Tobago     1376715    123       8        109       6          0
# Bahamas                  405714    104      11         72      21          1
# ...

# %%
ax = result['Rate of Infection'].sort_values(ascending=False).plot(kind='bar')
plt.show()

# %%
result['Mortality pct'].sort_values(ascending=False).round(2)
# Out:
# Country/Region
# Bahamas                10.58
# Barbados                7.22
# Trinidad and Tobago     6.50
# Curacao                 4.35
# Guatemala               3.90
# Cuba                    3.70
# Nicaragua               3.51
# Honduras                3.42
# Aruba                   2.97
# Dominican Republic      2.60
# Panama                  2.08
# El Salvador             1.93
# Jamaica                 1.61
# Costa Rica              0.67
# Saint Lucia             0.00
# Name: Mortality pct, dtype: float64

# %%
result['Mortality pct'].describe().round(2)
# Out:
# count    15.00
# mean      3.67
# std       2.71
# min       0.00
# 25%       2.00
# 50%       3.42
# 75%       4.12
# max      10.58
# Name: Mortality pct, dtype: float64

# %%
result['Mortality pct'].plot(kind='box', )
plt.show()
