# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
plt.rcParams['figure.figsize'] = [20,15]
import seaborn as sns
sns.set(palette='bright')

# %%
cases = pd.read_csv('/home/andres/Documents/JupyterNBs/COVID_19_Data/COVID_Analysis/All_CAMCAR_Cases.csv',index_col=0)
deaths = pd.read_csv('/home/andres/Documents/JupyterNBs/COVID_19_Data/COVID_Analysis/All_CAMCAR_Deaths.csv',index_col=0)
recovered = pd.read_csv('/home/andres/Documents/JupyterNBs/COVID_19_Data/COVID_Analysis/All_CAMCAR_Recovered.csv',index_col=0)

# %%
cases
# Out:
#     Province/State       Country/Region  7/26/20  7/27/20
# 0              NaN   Dominican Republic    62908    64156
# 1              NaN               Panama    60296    61442
# 2              NaN            Guatemala    45053    45309
# 3              NaN             Honduras    39276    39741
# 4              NaN           Costa Rica    15229    15841
# 5              NaN          El Salvador    14630    15035
# 6    French Guiana               France     7332     7514
# 7              NaN                Haiti     7315     7340
# 8              NaN            Nicaragua     3439     3439
# 9              NaN                 Cuba     2495     2532
# 10             NaN              Jamaica      842      853
# 11             NaN               Guyana      370      389
# 12             NaN              Bahamas      342      382
# 13  Cayman Islands       United Kingdom      203      203
# 14             NaN  Trinidad and Tobago      147      148
# ...

# %%
deaths.head()
# Out:
#   Province/State      Country/Region  7/26/20  7/27/20
# 0            NaN           Guatemala     1734     1761
# 1            NaN              Panama     1294     1322
# 2            NaN            Honduras     1116     1166
# 3            NaN  Dominican Republic     1063     1083
# 4            NaN         El Salvador      400      408

# %%
recovered.head()
# Out:
#   Province/State      Country/Region  7/26/20  7/27/20
# 0            NaN              Panama    34131    35086
# 1            NaN           Guatemala    31612    32455
# 2            NaN  Dominican Republic    28603    30204
# 3            NaN         El Salvador     7648     7778
# 4  French Guiana              France     5767     6047

# %%
names_cases = cases[cases['Province/State'].notna()].iloc[:,0]
indices = names_cases.index

# %%
cases.iloc[indices, 1] = names_cases

# %%
cases.drop('Province/State', axis=1, inplace=True)

# %%
cases
# Out:
#          Country/Region  7/26/20  7/27/20
# 0    Dominican Republic    62908    64156
# 1                Panama    60296    61442
# 2             Guatemala    45053    45309
# 3              Honduras    39276    39741
# 4            Costa Rica    15229    15841
# 5           El Salvador    14630    15035
# 6         French Guiana     7332     7514
# 7                 Haiti     7315     7340
# 8             Nicaragua     3439     3439
# 9                  Cuba     2495     2532
# 10              Jamaica      842      853
# 11               Guyana      370      389
# 12              Bahamas      342      382
# 13       Cayman Islands      203      203
# 14  Trinidad and Tobago      147      148
# 15                Aruba      119      119
# 16         Sint Maarten      114      114
# 17             Barbados      110      110
# 18  Antigua and Barbuda       82       86
# 19            St Martin       49       49
# 20              Curacao       29       29
# ...

# %%
names_deaths = deaths[deaths['Province/State'].notna()].iloc[:,0]
indices = names_deaths.index
deaths.iloc[indices, 1] = names_deaths
deaths.drop('Province/State', axis=1, inplace=True)
deaths
# Out:
#          Country/Region  7/26/20  7/27/20
# 0             Guatemala     1734     1761
# 1                Panama     1294     1322
# 2              Honduras     1116     1166
# 3    Dominican Republic     1063     1083
# 4           El Salvador      400      408
# 5                 Haiti      157      158
# 6            Costa Rica      104      115
# 7             Nicaragua      108      108
# 8                  Cuba       87       87
# 9         French Guiana       41       42
# 10               Guyana       20       20
# 11         Sint Maarten       15       15
# 12              Bahamas       11       11
# 13              Jamaica       10       10
# 14  Trinidad and Tobago        8        8
# 15             Barbados        7        7
# 16  Antigua and Barbuda        3        3
# 17                Aruba        3        3
# 18            St Martin        3        3
# 19              Curacao        1        1
# 20       Cayman Islands        1        1
# ...

# %%
names_recovered = recovered[recovered['Province/State'].notna()].iloc[:,0]
indices = names_recovered.index
recovered.iloc[indices, 1] = names_recovered
recovered.drop('Province/State', axis=1, inplace=True)
recovered
# Out:
#          Country/Region  7/26/20  7/27/20
# 0                Panama    34131    35086
# 1             Guatemala    31612    32455
# 2    Dominican Republic    28603    30204
# 3           El Salvador     7648     7778
# 4         French Guiana     5767     6047
# 5              Honduras     4922     5039
# 6                 Haiti     4365     4365
# 7            Costa Rica     3736     3824
# 8             Nicaragua     2492     2492
# 9                  Cuba     2349     2351
# 10              Jamaica      714      714
# 11       Cayman Islands      202      202
# 12               Guyana      181      181
# 13  Trinidad and Tobago      128      128
# 14                Aruba      102      102
# 15             Barbados       94       94
# 16              Bahamas       91       91
# 17  Antigua and Barbuda       60       65
# 18         Sint Maarten       63       63
# 19            St Martin       41       41
# 20              Curacao       24       24
# ...

# %%
cases.set_index('Country/Region', inplace=True)
deaths.set_index('Country/Region', inplace=True)
recovered.set_index('Country/Region', inplace=True)

# %%
cases
# Out:
#                      7/26/20  7/27/20
# Country/Region
# Dominican Republic     62908    64156
# Panama                 60296    61442
# Guatemala              45053    45309
# Honduras               39276    39741
# Costa Rica             15229    15841
# El Salvador            14630    15035
# French Guiana           7332     7514
# Haiti                   7315     7340
# Nicaragua               3439     3439
# Cuba                    2495     2532
# Jamaica                  842      853
# Guyana                   370      389
# Bahamas                  342      382
# Cayman Islands           203      203
# Trinidad and Tobago      147      148
# Aruba                    119      119
# Sint Maarten             114      114
# Barbados                 110      110
# Antigua and Barbuda       82       86
# St Martin                 49       49
# Curacao                   29       29
# Saint Lucia               24       24

# %%
deaths
# Out:
#                      7/26/20  7/27/20
# Country/Region
# Guatemala               1734     1761
# Panama                  1294     1322
# Honduras                1116     1166
# Dominican Republic      1063     1083
# El Salvador              400      408
# Haiti                    157      158
# Costa Rica               104      115
# Nicaragua                108      108
# Cuba                      87       87
# French Guiana             41       42
# Guyana                    20       20
# Sint Maarten              15       15
# Bahamas                   11       11
# Jamaica                   10       10
# Trinidad and Tobago        8        8
# Barbados                   7        7
# Antigua and Barbuda        3        3
# Aruba                      3        3
# St Martin                  3        3
# Curacao                    1        1
# Cayman Islands             1        1
# Saint Lucia                0        0

# %%
indices = cases.index
indices
# Out:
# Index(['Dominican Republic', 'Panama', 'Guatemala', 'Honduras', 'Costa Rica',
#        'El Salvador', 'French Guiana', 'Haiti', 'Nicaragua', 'Cuba', 'Jamaica',
#        'Guyana', 'Bahamas', 'Cayman Islands', 'Trinidad and Tobago', 'Aruba',
#        'Sint Maarten', 'Barbados', 'Antigua and Barbuda', 'St Martin',
#        'Curacao', 'Saint Lucia'],
#       dtype='object', name='Country/Region')

# %%
deaths = deaths.reindex(indices)
deaths
# Out:
#                      7/26/20  7/27/20
# Country/Region
# Dominican Republic      1063     1083
# Panama                  1294     1322
# Guatemala               1734     1761
# Honduras                1116     1166
# Costa Rica               104      115
# El Salvador              400      408
# French Guiana             41       42
# Haiti                    157      158
# Nicaragua                108      108
# Cuba                      87       87
# Jamaica                   10       10
# Guyana                    20       20
# Bahamas                   11       11
# Cayman Islands             1        1
# Trinidad and Tobago        8        8
# Aruba                      3        3
# Sint Maarten              15       15
# Barbados                   7        7
# Antigua and Barbuda        3        3
# St Martin                  3        3
# Curacao                    1        1
# Saint Lucia                0        0

# %%
recovered = recovered.reindex(indices)
recovered
# Out:
#                      7/26/20  7/27/20
# Country/Region
# Dominican Republic     28603    30204
# Panama                 34131    35086
# Guatemala              31612    32455
# Honduras                4922     5039
# Costa Rica              3736     3824
# El Salvador             7648     7778
# French Guiana           5767     6047
# Haiti                   4365     4365
# Nicaragua               2492     2492
# Cuba                    2349     2351
# Jamaica                  714      714
# Guyana                   181      181
# Bahamas                   91       91
# Cayman Islands           202      202
# Trinidad and Tobago      128      128
# Aruba                    102      102
# Sint Maarten              63       63
# Barbados                  94       94
# Antigua and Barbuda       60       65
# St Martin                 41       41
# Curacao                   24       24
# Saint Lucia               22       22

# %%
day = cases.columns.values[-1]
day
# Out:
# '7/27/20'

# %%
active = pd.DataFrame(cases - deaths - recovered)

# %%
active
# Out:
#                      7/26/20  7/27/20
# Country/Region
# Dominican Republic     33242    32869
# Panama                 24871    25034
# Guatemala              11707    11093
# Honduras               33238    33536
# Costa Rica             11389    11902
# El Salvador             6582     6849
# French Guiana           1524     1425
# Haiti                   2793     2817
# Nicaragua                839      839
# Cuba                      59       94
# Jamaica                  118      129
# Guyana                   169      188
# Bahamas                  240      280
# Cayman Islands             0        0
# Trinidad and Tobago       11       12
# Aruba                     14       14
# Sint Maarten              36       36
# Barbados                   9        9
# Antigua and Barbuda       19       18
# St Martin                  5        5
# Curacao                    4        4
# Saint Lucia                2        2

# %%
ax = cases[day].plot.barh(color=[1,0,0,1], x='Country/Region', y=day, label='Total Confirmed Cases')
active[day].plot.barh(ax=ax, color=[1,0.9,0,1], label='Active Cases')
deaths[day].plot.barh(ax=ax, color=[0,0,0,1], label='Deaths')
recovered[day].plot.barh(ax=ax, color=[0,1,0,0.5], label='Recovered')
plt.yticks(fontsize=20, rotation=0)
plt.ylabel(day, fontsize=30)
plt.xticks(np.arange(0, cases.iloc[cases[day].argmax(), 1], 25),fontsize=15, rotation=45)
plt.title('COVID-19 CAMCAR', fontsize=25)
plt.legend(loc='best', fontsize=25)
plt.show()

# %%
joined_data = pd.DataFrame(cases[day])
joined_data
# Out:
#                      7/27/20
# Country/Region
# Dominican Republic     64156
# Panama                 61442
# Guatemala              45309
# Honduras               39741
# Costa Rica             15841
# El Salvador            15035
# French Guiana           7514
# Haiti                   7340
# Nicaragua               3439
# Cuba                    2532
# Jamaica                  853
# Guyana                   389
# Bahamas                  382
# Cayman Islands           203
# Trinidad and Tobago      148
# Aruba                    119
# Sint Maarten             114
# Barbados                 110
# Antigua and Barbuda       86
# St Martin                 49
# Curacao                   29
# Saint Lucia               24

# %%
joined_data.rename(columns={day: 'Cases'}, inplace=True)

# %%
joined_data['Deaths'] = deaths[day]

# %%
joined_data['Recovered'] = recovered[day]

# %%
joined_data['Active'] = active[day]

# %%
joined_data['New Cases'] = cases.iloc[:,-1] - cases.iloc[:,-2]

# %%
joined_data
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases
# Country/Region
# Dominican Republic   64156    1083      30204   32869       1248
# Panama               61442    1322      35086   25034       1146
# Guatemala            45309    1761      32455   11093        256
# Honduras             39741    1166       5039   33536        465
# Costa Rica           15841     115       3824   11902        612
# El Salvador          15035     408       7778    6849        405
# French Guiana         7514      42       6047    1425        182
# Haiti                 7340     158       4365    2817         25
# Nicaragua             3439     108       2492     839          0
# Cuba                  2532      87       2351      94         37
# Jamaica                853      10        714     129         11
# Guyana                 389      20        181     188         19
# Bahamas                382      11         91     280         40
# ...

# %%
joined_data.to_csv('All_CAMCAR_Latest_Cases_Deaths_Recovered_Active.csv', index=True)

# %%
joined_data.plot(kind='barh', cmap=plt.get_cmap('jet'))
plt.yticks(fontsize=20, rotation=0)
plt.ylabel(day, fontsize=30)
plt.xticks(np.arange(0, cases.iloc[cases[day].argmax(), 1], 50),fontsize=15, rotation=45)
plt.title('COVID-19 CAMCAR Data', fontsize=25)
plt.legend(loc='best', fontsize=25)
plt.show()

# %%
joined_data.describe()
# Out:
#               Cases       Deaths     Recovered        Active    New Cases
# count     22.000000    22.000000     22.000000     22.000000    22.000000
# mean   12038.863636   287.818182   5971.272727   5779.772727   202.318182
# std    20634.588990   524.877458  11085.616082  10733.217260   366.959760
# min       24.000000     0.000000     22.000000      0.000000     0.000000
# 25%      115.250000     4.000000     91.750000     12.500000     0.000000
# 50%      621.000000    17.500000    458.000000    158.500000    15.000000
# 75%    13154.750000   147.250000   4870.500000   5841.000000   237.500000
# max    64156.000000  1761.000000  35086.000000  33536.000000  1248.000000

# %%
# cols =joined_data.columns.values
# cols[0], cols[1], cols[2], cols[3] = cols[1], cols[2], cols[3], cols[0]
# cols

# %%
data_bar = joined_data.sort_values(by=['Cases'])
#data_bar = data_bar[cols]
data_bar
# Out:
#                      Cases  Deaths  Recovered  Active  New Cases
# Country/Region
# Saint Lucia             24       0         22       2          0
# Curacao                 29       1         24       4          0
# St Martin               49       3         41       5          0
# Antigua and Barbuda     86       3         65      18          4
# Barbados               110       7         94       9          0
# Sint Maarten           114      15         63      36          0
# Aruba                  119       3        102      14          0
# Trinidad and Tobago    148       8        128      12          1
# Cayman Islands         203       1        202       0          0
# Bahamas                382      11         91     280         40
# Guyana                 389      20        181     188         19
# Jamaica                853      10        714     129         11
# Cuba                  2532      87       2351      94         37
# ...

# %%
data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].plot(kind='barh', cmap=plt.get_cmap('seismic'))
plt.yticks(fontsize=20, rotation=0)
plt.ylabel('', fontsize=30)
plt.xticks(np.arange(0, cases.iloc[cases[day].argmax(), 1], 100),fontsize=15, rotation=45)
plt.title('COVID-19 CAMCAR Data   ' + day, fontsize=25)
plt.legend(loc=4, fontsize=25)
columns = data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].shape[1]
rows = data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].shape[0]
ys = np.array(range(rows))
for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,0] + 5, 
        y=ys[i] - 0.25, 
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,0], 
        size=20
    )


for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,1] + 5, 
        y=ys[i] -0.1 if data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,2] != 0 else 0.1, 
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,1], 
        size=18
    )


for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,2] + 10, 
        y=ys[i] , 
        s= data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,2], 
        size=18
    )

for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,3] + 5, 
        y=ys[i] + 0.15, 
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,3], 
        size=20
    )
plt.savefig('/home/andres/Documents/JupyterNBs/COVID_19_Data/Figures/CAMCAR_Largest.png')
plt.show()

# %%
data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[1,0]
# Out:
# 2532

# %%
data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].columns.values[0]
# Out:
# 'Cases'

# %%
data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)]
# Out:
#                     Cases  Deaths  Recovered  Active  New Cases
# Country/Region
# Jamaica               853      10        714     129         11
# Cuba                 2532      87       2351      94         37
# Nicaragua            3439     108       2492     839          0
# Haiti                7340     158       4365    2817         25
# French Guiana        7514      42       6047    1425        182
# El Salvador         15035     408       7778    6849        405
# Costa Rica          15841     115       3824   11902        612
# Honduras            39741    1166       5039   33536        465
# Guatemala           45309    1761      32455   11093        256
# Panama              61442    1322      35086   25034       1146
# Dominican Republic  64156    1083      30204   32869       1248

# %%
data_bar.plot(kind='barh', cmap=plt.get_cmap('seismic'))
plt.yticks(fontsize=20, rotation=0)
plt.ylabel(day, fontsize=30)
plt.xticks(np.arange(0, cases.iloc[cases[day].argmax(), 1], 100),fontsize=15, rotation=45)
plt.title('COVID-19 CAMCAR Data', fontsize=25)
plt.legend(loc=4, fontsize=25)
plt.savefig('/home/andres/Documents/JupyterNBs/COVID_19_Data/Figures/CAMCAR_All.png')
plt.show()

# %%
data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].plot(
    kind='barh', cmap=plt.get_cmap('rainbow')
)
plt.yticks(fontsize=20, rotation=0)
plt.ylabel('', fontsize=30)
plt.xticks(np.arange(0, cases.iloc[cases[day].argmax(), 1].round(-1), 100),fontsize=15, rotation=45)
plt.xscale('log')
#plt.ticklabel_format(style='plain', axis='y')
plt.title('COVID-19 CAMCAR Data   ' + day, fontsize=25)
plt.legend(loc=4, fontsize=25)
columns = data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].shape[1]
rows = data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].shape[0]
ys = np.array(range(rows))
for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,0] + 5, 
        y=ys[i] - 0.25, 
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,0], 
        size=20
    )


for i in range(rows):
    plt.text( create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports/07-26-2020.csv
 create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports/07-27-2020.csv
 create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports_us/07-21-2020.csv
 create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports_us/07-22-2020.csv
 create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports_us/07-23-2020.csv
 create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports_us/07-24-2020.csv
 create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports_us/07-25-2020.csv
 create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports_us/07-26-2020.csv
 create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports_us/07-27-2020.csv
(base) andres@skynet:~/Documents/JupyterNBs/COVID_19_Data/JHUH_Data$ cd  ..
(base) andres@skynet:~/Documents/JupyterNBs/COVID_19_Data$ cd COVID_Analysis/
(base) andres@skynet:~/Documents/JupyterNBs/COVID_19_Data/COVID_Ana
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,1] + 0.1  if data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,1] != 0 else 0.9, 
        y=ys[i] -0.125, 
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,1], 
        size=18
    )


for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,2] + 0.1, 
        y=ys[i] -0.05, 
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,2], 
        size=18
    )

for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,3] + 5, 
        y=ys[i] + 0.05,
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,3], 
        size=20
    )

for i in range(rows):
    plt.text(
        x=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,4] + 5, 
        y=ys[i] + 0.15, 
        s=data_bar[data_bar['Cases'] > data_bar['Cases'].quantile(0.5)].iloc[i,4], 
        size=20
    )
plt.savefig('/home/andres/Documents/JupyterNBs/COVID_19_Data/Figures/CAMCAR_Largest_log.png')
plt.show()
